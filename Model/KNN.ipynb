# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data_finnal_12_lead.csv")
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#                         FileName  Rhythm  PatientAge  Gender  Rcount_lead1  \
# 0     MUSE_20180113_171327_27000       0          85       1          14.0
# 1     MUSE_20180112_073319_29000       1          59       0           8.0
# 2     MUSE_20180111_165520_97000       2          20       0          11.0
# 3     MUSE_20180113_121940_44000       1          66       1           9.0
# 4     MUSE_20180112_120347_79000       1          46       0           9.0
# ...                          ...     ...         ...     ...           ...
# 9671  MUSE_20180712_151718_88000       3          65       1          13.0
# 9672  MUSE_20180712_151721_02000       3          55       0          21.0
# 9673  MUSE_20180712_151744_19000       3          54       1          17.0
# 9674  MUSE_20180712_151746_33000       3          54       1          23.0
# 9675  MUSE_20181222_204131_50000       3          78       1          18.0
#
#       RRInterval_mean_lead1  RRInterval_median_lead1  RRInterval_std_lead1  \
# 0                709.230769                    540.0            455.907911
# 1               1160.571429                   1148.0             26.462141
# 2                898.800000                    891.0             52.032298
# 3               1125.500000                   1131.0             15.419144
# 4               1059.750000                   1065.0             23.333185
# ...                     ...                      ...                   ...
# 9671             774.500000                    598.0            653.429478
# 9672             457.300000                    456.0              2.984962
# 9673             576.250000                    594.0             48.522546
# 9674             425.272727                    426.0              5.832369
# 9675             562.705882                    330.0            365.029534
#
#       RRInterval_range_lead1  RRInterval_skew_lead1  ...  Rcount_lead12  \
# 0                     1626.0               2.299685  ...           19.0
# 1                       68.0               0.249879  ...            8.0
# 2                      154.0              -0.110608  ...           11.0
# 3                       42.0              -0.551365  ...            9.0
# 4                       64.0              -0.521012  ...            9.0
# ...                      ...                    ...  ...            ...
# 9671                  2402.0               2.151993  ...           14.0
# 9672                    10.0               0.159949  ...           21.0
# 9673                   152.0              -2.258661  ...           17.0
# 9674                    18.0              -0.111517  ...           23.0
# 9675                  1190.0               1.252508  ...           15.0
#
#       RRInterval_mean_lead12  RRInterval_median_lead12  RRInterval_std_lead12  \
# 0                 512.444444                     532.0              69.325498
# 1                1160.857143                    1148.0              26.680269
# 2                 899.000000                     893.0              52.124850
# 3                1125.750000                    1132.0              16.686447
# 4                1059.750000                    1066.0              23.290288
# ...                      ...                       ...                    ...
# 9671              590.461538                     600.0             177.343047
# 9672              457.400000                     456.0               2.973214
# 9673              595.125000                     594.0               2.642797
# 9674              425.090909                     426.0               5.869095
# 9675              583.000000                     614.0             252.037129
#
#       RRInterval_range_lead12  RRInterval_skew_lead12  \
# 0                       260.0               -0.212461
# 1                        68.0                0.230522
# 2                       154.0               -0.142739
# 3                        46.0               -0.602255
# 4                        64.0               -0.573407
# ...                       ...                     ...
# 9671                    780.0                0.975939
# 9672                     10.0                0.613624
# 9673                      8.0                0.514886
# 9674                     18.0                0.018730
# 9675                    756.0                0.386351
#
#       RRInterval_kurtosis_lead12  \
# 0                      -0.180702
# 1                      -1.706863
# 2                      -1.353505
# 3                      -1.189500
# 4                      -1.154060
# ...                          ...
# 9671                    2.616653
# 9672                   -0.682746
# 9673                   -0.876387
# 9674                   -1.292902
# 9675                   -1.105995
#
#       R_peaks_amplitude_from_isoelectric_mean_lead12  PRovercount_lead12  \
# 0                                         622.917926            0.631579
# 1                                         737.646851            1.000000
# 2                                         483.733038            1.000000
# 3                                        1229.775089            1.000000
# 4                                         934.189646            1.000000
# ...                                              ...                 ...
# 9671                                      486.754585            0.928571
# 9672                                      462.674633            0.761905
# 9673                                      300.997929            1.000000
# 9674                                     1850.887281            0.913043
# 9675                                      513.979685            0.733333
#
#       medianOfRInterSubMedianOfPInter_lead12
# 0                                       60.0
# 1                                        4.0
# 2                                      -35.0
# 3                                       21.0
# 4                                       -1.0
# ...                                      ...
# 9671                                     4.0
# 9672                                    -2.0
# 9673                                    -1.0
# 9674                                     4.0
# 9675                                   278.0
#
# [9676 rows x 124 columns]

# %%
X = df.iloc[:,2:].values
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,shuffle=True,stratify=y)
print(f"Train:{x_train.shape}")
print(f"Test:{x_test.shape}")
# Out:
# Train:(7740, 122)
# Test:(1936, 122)

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
from sklearn.metrics import confusion_matrix
def confusion_matrix_scorer(clf=None,X=None, y=None,y_pred=None,y_prob=None):
    if clf != None:
        y_pred = clf.predict(X)
        y_prob = clf.predict_proba(X)[:,1]
    cm = confusion_matrix(y,y_pred)
    acc_arr = []
    precision_arr = []
    recall_arr = []
    specificity_arr = []
    f1_arr = []
    for c in range(0,len(cm)):
        c = len(cm)-1
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc_arr.append((tp+tn) / (tp+fn+tn+fp))
        recall_arr.append(tp/(tp+fn))
        precision_arr.append(tp/(tp+fp))
        specificity_arr.append(tn/(tn+fp))
        f1_arr.append(2*(((tp/(tp+fp))*(tp/(tp+fn)))/((tp/(tp+fp))+(tp/(tp+fn)))))
    return {'acc':np.nanmean(acc_arr),'precision':np.nanmean(precision_arr),'specificity':np.nanmean(specificity_arr),'recall':np.nanmean(recall_arr),'f1_score':np.nanmean(f1_arr)}

# %%
NUMBER_FOLD = 10
def create_df_val(rs_cv):
    df_val = {
        "ACC":[],
        "precision":[],
        "specificity":[],
        "recall":[],
        "f1_score":[],
        "params":[]
    }
    LEN_PARAMS = len(rs_cv["params"])
    for i in range(NUMBER_FOLD):
        str_label = f"split{i}"
        df_val["ACC"].append(np.array(rs_cv[str_label+f"_test_acc"]))
        df_val["precision"].append(rs_cv[str_label+f"_test_precision"])
        df_val["specificity"].append(rs_cv[str_label+f"_test_specificity"])
        df_val["recall"].append(rs_cv[str_label+f"_test_recall"])
        df_val["f1_score"].append(rs_cv[str_label+f"_test_f1_score"])
        df_val["params"].append(rs_cv["params"])
    df_val["ACC"] = np.array(df_val["ACC"] ).flatten()
    df_val["precision"] = np.array(df_val["precision"] ).flatten()
    df_val["specificity"] = np.array(df_val["specificity"] ).flatten()
    df_val["recall"] = np.array(df_val["recall"] ).flatten()
    df_val["f1_score"] = np.array(df_val["f1_score"] ).flatten()
    df_val["params"] = np.array(df_val["params"] ).flatten()
    df_combine_val = pd.DataFrame(df_val).dropna(axis=0).sort_values(by="ACC",ascending=False)
    
    return df_combine_val

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
model = KNeighborsClassifier()
params = {
    'n_neighbors': [4,5,6],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'p': [1,2,3]
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=10, verbose=2, return_train_score=True,refit=False,scoring=confusion_matrix_scorer)
grid_model = grid_search.fit(x_train_sc,y_train)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   1.2s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.1s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  13.7s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.6s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=4, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  11.4s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  11.3s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=uniform; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.6s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=5, p=3, weights=distance; total time=  10.6s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.5s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.9s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.8s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.7s
# [CV] END algorithm=auto, n_neighbors=6, p=3, weights=distance; total time=  10.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.7s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   3.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   2.7s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=1, weights=distance; total time=   3.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.9s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=uniform; total time=   3.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.4s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=2, weights=distance; total time=   3.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  44.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  44.2s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  42.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  42.9s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  42.9s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  43.2s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  33.1s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  32.5s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  41.9s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=uniform; total time=  42.0s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  42.8s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  42.6s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  37.7s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  41.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  41.3s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  42.0s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  43.7s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  41.2s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  40.7s
# [CV] END algorithm=ball_tree, n_neighbors=4, p=3, weights=distance; total time=  37.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=1, weights=distance; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   2.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=uniform; total time=   3.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   3.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   3.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   3.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=2, weights=distance; total time=   3.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  44.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  43.8s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  39.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  42.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  42.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  40.1s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  40.7s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  42.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  42.6s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=uniform; total time=  42.7s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  43.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  43.8s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  42.5s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  45.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  43.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  43.2s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  43.0s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  44.3s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  41.7s
# [CV] END algorithm=ball_tree, n_neighbors=5, p=3, weights=distance; total time=  41.8s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=1, weights=distance; total time=   2.7s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  45.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  44.8s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.3s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.6s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  44.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  49.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.4s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=uniform; total time=  43.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  43.9s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  43.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  42.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  42.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  42.5s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  43.2s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  43.0s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  42.1s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  41.9s
# [CV] END algorithm=ball_tree, n_neighbors=6, p=3, weights=distance; total time=  41.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.3s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.6s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  19.7s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  19.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  17.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  18.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  19.1s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  17.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  17.9s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=uniform; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  19.2s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  19.0s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.6s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  18.6s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  19.2s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.5s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.4s
# [CV] END algorithm=kd_tree, n_neighbors=4, p=3, weights=distance; total time=  17.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  19.9s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  20.5s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.3s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.2s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.3s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  20.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  18.1s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=uniform; total time=  19.1s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  19.4s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  19.2s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.8s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.8s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  18.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.9s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.7s
# [CV] END algorithm=kd_tree, n_neighbors=5, p=3, weights=distance; total time=  17.7s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.6s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=uniform; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.6s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=1, weights=distance; total time=   2.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=uniform; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=2, weights=distance; total time=   1.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  20.1s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  21.9s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  20.0s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.3s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  19.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.7s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.3s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=uniform; total time=  18.3s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  19.5s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  19.4s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  19.9s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  19.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  18.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  18.0s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  17.9s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  17.8s
# [CV] END algorithm=kd_tree, n_neighbors=6, p=3, weights=distance; total time=  17.9s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=uniform; total time=   0.4s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.7s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.7s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.5s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.9s
# [CV] END algorithm=brute, n_neighbors=4, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=uniform; total time=   0.4s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  12.5s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  12.0s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   9.4s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.9s
# [CV] END algorithm=brute, n_neighbors=5, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=uniform; total time=   0.3s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.4s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.5s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=1, weights=distance; total time=   0.2s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=uniform; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=2, weights=distance; total time=   0.0s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  12.3s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.2s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.9s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.3s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.9s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.1s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=uniform; total time=  11.0s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.8s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.7s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.7s
# [CV] END algorithm=brute, n_neighbors=6, p=3, weights=distance; total time=   8.6s

# %%
# Validation of each fold 
evaluation_validation = create_df_val(grid_model.cv_results_).reset_index().drop(columns=["index"])
evaluation_validation
# Out:
#           ACC  precision  specificity    recall  f1_score  \
# 0    0.981912   0.959016     0.992284  0.928571  0.943548
# 1    0.981912   0.959016     0.992284  0.928571  0.943548
# 2    0.981912   0.959016     0.992284  0.928571  0.943548
# 3    0.981912   0.959016     0.992284  0.928571  0.943548
# 4    0.980620   0.951220     0.990741  0.928571  0.939759
# ..        ...        ...          ...       ...       ...
# 715  0.936693   0.896907     0.984568  0.690476  0.780269
# 716  0.932817   0.893617     0.984568  0.666667  0.763636
# 717  0.932817   0.893617     0.984568  0.666667  0.763636
# 718  0.932817   0.893617     0.984568  0.666667  0.763636
# 719  0.932817   0.893617     0.984568  0.666667  0.763636
#
#                                                 params
# 0    {'algorithm': 'brute', 'n_neighbors': 6, 'p': ...
# 1    {'algorithm': 'kd_tree', 'n_neighbors': 6, 'p'...
# 2    {'algorithm': 'ball_tree', 'n_neighbors': 6, '...
# 3    {'algorithm': 'auto', 'n_neighbors': 6, 'p': 1...
# 4    {'algorithm': 'ball_tree', 'n_neighbors': 6, '...
# ..                                                 ...
# 715  {'algorithm': 'brute', 'n_neighbors': 6, 'p': ...
# 716  {'algorithm': 'brute', 'n_neighbors': 4, 'p': ...
# 717  {'algorithm': 'ball_tree', 'n_neighbors': 4, '...
# 718  {'algorithm': 'auto', 'n_neighbors': 4, 'p': 3...
# 719  {'algorithm': 'kd_tree', 'n_neighbors': 4, 'p'...
#
# [720 rows x 6 columns]

# %%
evaluation_validation.to_csv("../Result/KNN_12_lead_validation.csv")

# %%
evaluation_validation = pd.read_csv("../Result/KNN_12_lead_validation.csv")
evaluation_validation.drop(columns=['Unnamed: 0'],inplace=True)
evaluation_validation["mean"] = evaluation_validation.iloc[:,0:-1].mean(axis=1)
evaluation_validation = evaluation_validation.sort_values(by='mean',ascending=False)

# %%
import json
import ast
params_optimal = (evaluation_validation.iloc[0,:]['params'])


input_string = params_optimal

# Convert the string into a Python dictionary
data_dict = ast.literal_eval(input_string)

# Convert the dictionary into JSON
params_optimal = json.loads(json.dumps(data_dict))

print(params_optimal)
# Out:
# {'algorithm': 'brute', 'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}

# %%
# params_optimal = evaluation_validation.iloc[0,:]['params']

# %%
params_optimal
# Out:
# {'algorithm': 'brute', 'n_neighbors': 6, 'p': 1, 'weights': 'uniform'}

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=params_optimal['n_neighbors'],weights=params_optimal['weights'],p=params_optimal['p'])
model.fit(x_train_sc,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6, p=1)

# %%
result_test = model.predict(x_test_sc)
evaluation_test = confusion_matrix_scorer(None,None,y_test,result_test,None)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,r_macro,p_macro,f_macro,None])
    result.append(['micro avg',None,r_micro,p_micro,f_micro,None])
    result.append(['weighted avg',None,r_weighted,p_weighted,f_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","Recall","Precision","F1-score","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC    Recall  Precision  F1-score  specificity
# 0          AFIB  0.955579  0.919315   0.876457  0.897375     0.965291
# 1            SB  0.974690  0.985696   0.952261  0.968690     0.967438
# 2            SR  0.963843  0.893665   0.944976  0.918605     0.984605
# 3          GSVT  0.967459  0.863924   0.931741  0.896552     0.987654
# 4     macro avg       NaN  0.915650   0.926359  0.920305          NaN
# 5     micro avg       NaN  0.930785   0.930785  0.930785          NaN
# 6  weighted avg       NaN  0.930785   0.931234  0.930415          NaN

# %%
df_evaluation_test.to_csv("../Result/KNN_12_lead_test_mean.csv")
