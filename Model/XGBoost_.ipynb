# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data_train_125ft.csv")
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#         0     1    2     3            4       5           6      7         8  \
# 0     0.0  87.0  1.0  14.0   712.000000   696.0   65.440519  240.0  0.703359
# 1     2.0  49.0  1.0  13.0   712.000000   691.0   47.300458  158.0  0.884010
# 2     1.0  86.0  1.0   9.0  1096.250000  1098.0    8.150920   28.0 -0.156675
# 3     1.0  70.0  1.0   8.0  1169.714286  1168.0    4.463000   14.0  0.642283
# 4     3.0  61.0  0.0  16.0   585.333333   586.0    2.890598   12.0  0.196283
# ...   ...   ...  ...   ...          ...     ...         ...    ...       ...
# 8343  0.0  72.0  1.0  16.0   619.466667   592.0  139.659522  480.0  0.480046
# 8344  3.0  23.0  0.0  19.0   510.777778   512.0    7.091118   30.0 -0.059891
# 8345  1.0  51.0  0.0   9.0  1090.250000  1088.0    9.769212   30.0  0.213875
# 8346  3.0  45.0  0.0  26.0   370.320000   370.0    3.133305   10.0  0.358316
# 8347  1.0  28.0  1.0   9.0  1037.000000  1037.0   28.372522   94.0 -0.267952
#
#              9  ...          114     115         116    117       118  \
# 0    -0.246387  ...   712.000000   696.0   65.707979  240.0  0.699256
# 1    -0.332635  ...   712.000000   691.0   47.483330  156.0  0.894198
# 2    -0.642487  ...  1096.000000  1098.0    8.426150   28.0 -0.160466
# 3    -0.722722  ...  1169.428571  1168.0    4.237828   14.0  0.827427
# 4     0.113400  ...   585.333333   586.0    3.155243   12.0  0.354663
# ...        ...  ...          ...     ...         ...    ...       ...
# 8343 -0.842798  ...   619.466667   594.0  139.562109  482.0  0.472791
# 8344 -0.269851  ...   510.888889   512.0    6.870944   28.0  0.081059
# 8345 -1.152589  ...  1090.250000  1088.0    8.742854   28.0  0.436427
# 8346 -0.885061  ...   370.400000   370.0    3.098387   12.0  0.051640
# 8347 -0.810638  ...  1037.000000  1037.0   28.705400   94.0 -0.237050
#
#            119          120       121   122   123
# 0    -0.277091   783.821985  0.785714   9.0   6.0
# 1    -0.355280   380.188159  1.000000  13.0  12.0
# 2    -0.801230   808.359965  1.000000   8.0   6.0
# 3    -0.140248  1150.133430  1.000000   8.0   7.0
# 4    -0.484056   198.042444  1.000000  16.0  15.0
# ...        ...          ...       ...   ...   ...
# 8343 -0.825913   468.155165  1.000000  16.0   8.0
# 8344 -0.433829   309.210006  1.000000  19.0  18.0
# 8345 -0.891096   940.155678  1.000000   9.0   8.0
# 8346 -0.703333   856.813033  0.461538   1.0   6.0
# 8347 -0.876580   495.494523  1.000000   9.0   8.0
#
# [8348 rows x 124 columns]

# %%
x_train = df.iloc[:,1:].values
y_train = df.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train , test_size=0.5, shuffle=True, stratify=y_train, random_state=119)
print(f"Train: {x_train.shape}")
print(f"Vallidation: {x_val.shape}")
# Out:
# Train: (4174, 123)
# Vallidation: (4174, 123)

# %%
X = x_train
y = y_train

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)

# %%
from sklearn.metrics import confusion_matrix
def confusion_matrix_scorer(clf=None,X=None, y=None,y_pred=None,y_prob=None):
    if clf != None:
        y_pred = clf.predict(X)
        y_prob = clf.predict_proba(X)[:,1]
    cm = confusion_matrix(y,y_pred)
    acc_arr = []
    precision_arr = []
    recall_arr = []
    specificity_arr = []
    f1_arr = []
    for c in range(0,len(cm)):
        c = len(cm)-1
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc_arr.append((tp+tn) / (tp+fn+tn+fp))
        recall_arr.append(tp/(tp+fn))
        precision_arr.append(tp/(tp+fp))
        specificity_arr.append(tn/(tn+fp))
        f1_arr.append(2*(((tp/(tp+fp))*(tp/(tp+fn)))/((tp/(tp+fp))+(tp/(tp+fn)))))
    return {'acc':np.nanmean(acc_arr),'precision':np.nanmean(precision_arr),'specificity':np.nanmean(specificity_arr),'recall':np.nanmean(recall_arr),'f1_score':np.nanmean(f1_arr)}

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
model = XGBClassifier()
params = {
    'n_estimators': [10,50,100,1000],
    'learning_rate': [0.01,0.1,1,10],
    'max_depth': [3,4,5],
    'min_child_weight':[1],
    'gamma':[0,0.1,0.2],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X,y)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.939, test=0.920) total time=   1.4s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.928, test=0.921) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.936, test=0.924) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.940, test=0.917) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.939, test=0.927) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.936, test=0.925) total time=   0.3s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.944, test=0.920) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.928) total time=   0.5s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.932) total time=   0.6s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.940) total time=   5.7s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.948) total time=   6.7s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.986, test=0.940) total time=   5.9s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.951, test=0.918) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.948, test=0.925) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.946, test=0.930) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.930) total time=   0.5s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.4s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.4s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.935) total time=   1.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.956, test=0.936) total time=   1.2s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.935) total time=   1.3s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.943) total time=   8.8s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=  10.8s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.939) total time=   8.9s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.925) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.927) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.933) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.929) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.931) total time=   0.7s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.937) total time=   0.7s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.973, test=0.931) total time=   1.7s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.935) total time=   1.7s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.939) total time=   1.6s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=  16.4s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.950) total time= 1.1min
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=  37.9s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.945, test=0.920) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.944, test=0.927) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.943, test=0.932) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.971, test=0.932) total time=   0.9s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.941) total time=   0.6s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.968, test=0.942) total time=   1.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.943) total time=   2.4s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.950) total time=   7.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.987, test=0.941) total time=   5.4s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=  14.9s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.953) total time=  41.2s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=  18.2s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.937) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.935) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.933) total time=   0.5s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.944) total time=   0.5s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.985, test=0.937) total time=   0.5s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.939) total time=   1.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   1.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.941) total time=   1.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.943) total time=   5.5s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.953) total time=   6.8s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   6.5s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.930) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.937) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.938) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.938) total time=   0.9s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.945) total time=   0.9s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.995, test=0.942) total time=   0.9s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   1.6s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.949) total time=   1.7s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.944) total time=   1.6s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.946) total time=   6.7s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.953) total time=   7.5s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=   6.5s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.936) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.994, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.936) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.937) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.951) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.3s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.938) total time=   0.5s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.950) total time=   0.6s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.941) total time=   0.5s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   2.9s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.949) total time=   3.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   3.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.944) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.933) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.944) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.949) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.3s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.943) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.949) total time=   0.5s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.944) total time=   0.5s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   3.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   2.9s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.943) total time=   3.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.931) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.937) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.954) total time=   0.4s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.948) total time=   0.4s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.938) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.953) total time=   0.6s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.6s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.938) total time=   2.8s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.949) total time=   2.9s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   3.2s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.654, test=0.646) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.401, test=0.400) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.654, test=0.646) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.401, test=0.400) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.654, test=0.646) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.771, test=0.774) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.401, test=0.400) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.654, test=0.646) total time=   2.6s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.771, test=0.774) total time=   2.7s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.401, test=0.400) total time=   2.5s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.670, test=0.660) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.371, test=0.371) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.668, test=0.670) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.670, test=0.660) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.371, test=0.371) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.668, test=0.670) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.670, test=0.660) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.371, test=0.371) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.668, test=0.670) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.670, test=0.660) total time=   2.5s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.371, test=0.371) total time=   2.4s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.668, test=0.670) total time=   2.6s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.735, test=0.715) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.705, test=0.705) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.212, test=0.213) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.735, test=0.715) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.705, test=0.705) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.212, test=0.213) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.735, test=0.715) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.705, test=0.705) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.212, test=0.213) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.735, test=0.715) total time=   2.3s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.705, test=0.705) total time=   2.4s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.212, test=0.213) total time=   2.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.939, test=0.920) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.928, test=0.921) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.936, test=0.924) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.940, test=0.917) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.939, test=0.927) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.936, test=0.925) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.944, test=0.920) total time=   0.7s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.928) total time=   0.7s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.932) total time=   0.8s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.940) total time=   7.9s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.946) total time=   8.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.986, test=0.940) total time=   8.8s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.951, test=0.918) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.948, test=0.925) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.946, test=0.930) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.930) total time=   1.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.8s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.7s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.935) total time=   1.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.956, test=0.936) total time=   1.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.935) total time=   1.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=  11.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=  11.8s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.938) total time=  11.8s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.925) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.927) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.933) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.929) total time=   1.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.931) total time=   1.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.937) total time=   1.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.973, test=0.931) total time=   2.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.934) total time=   2.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.939) total time=   2.7s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.937) total time=  18.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.950) total time=  15.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=  13.5s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.945, test=0.920) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.944, test=0.927) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.943, test=0.932) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.971, test=0.934) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.942) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.968, test=0.942) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.941) total time=   0.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.949) total time=   0.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.941) total time=   0.7s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   3.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.949) total time=   3.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   3.8s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.937) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.935) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.934) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.943) total time=   1.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.985, test=0.939) total time=   0.9s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   1.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.947) total time=   1.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.942) total time=   1.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.944) total time=   2.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.950) total time=   2.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   2.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.930) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.937) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.938) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.938) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.945) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.942) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   0.8s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   1.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   1.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.941) total time=   2.7s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   2.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   3.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.992, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.935) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.936) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.944) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.936) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.944) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.936) total time=   1.9s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.944) total time=   1.8s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.941) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.940) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.940) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.939) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   1.5s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=   1.5s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.939) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.934) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.935) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.935) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.935) total time=   1.8s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=   1.6s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   1.7s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.654, test=0.646) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.401, test=0.400) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.654, test=0.646) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.401, test=0.400) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.654, test=0.646) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.401, test=0.400) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.654, test=0.646) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.771, test=0.774) total time=   1.4s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.401, test=0.400) total time=   1.4s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.670, test=0.660) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.371, test=0.371) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.668, test=0.670) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.670, test=0.660) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.371, test=0.371) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.668, test=0.670) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.670, test=0.660) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.371, test=0.371) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.668, test=0.670) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.670, test=0.660) total time=   1.4s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.371, test=0.371) total time=   1.3s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.668, test=0.670) total time=   1.4s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.735, test=0.715) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.705, test=0.705) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.212, test=0.213) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.735, test=0.715) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.705, test=0.705) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.212, test=0.213) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.735, test=0.715) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.705, test=0.705) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.212, test=0.213) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.735, test=0.715) total time=   1.4s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.705, test=0.705) total time=   1.5s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.212, test=0.213) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.939, test=0.920) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.928, test=0.921) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.936, test=0.924) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.940, test=0.917) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.939, test=0.927) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.936, test=0.925) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.944, test=0.920) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.928) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.943, test=0.932) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.940) total time=   4.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.947) total time=   4.6s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.986, test=0.940) total time=   4.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.951, test=0.918) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.948, test=0.925) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.946, test=0.930) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.930) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.953, test=0.933) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.935) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.956, test=0.936) total time=   0.7s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.935) total time=   0.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   6.6s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.949) total time=   6.8s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.939) total time=   6.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.926) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.927) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.933) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.969, test=0.929) total time=   0.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.932) total time=   0.5s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.937) total time=   0.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.974, test=0.931) total time=   1.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.935) total time=   1.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.939) total time=   1.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.936) total time=   7.9s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   8.9s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   9.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.945, test=0.920) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.944, test=0.927) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.943, test=0.932) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.971, test=0.933) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.967, test=0.942) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.968, test=0.942) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.941) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.949) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.939) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.944) total time=   1.9s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.950) total time=   1.9s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   2.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.962, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.937) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.935) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.937) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.942) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.940) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.6s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.942) total time=   0.6s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   2.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.950) total time=   2.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   2.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.930) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.937) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.938) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.940) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.998, test=0.945) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.942) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.938) total time=   0.8s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.8s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.939) total time=   0.8s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   2.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.949) total time=   2.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.939) total time=   2.3s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.992, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.993, test=0.941) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.934) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.934) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.934) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.934) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.948) total time=   1.4s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.938) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.937) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.934) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.939) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.934) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.939) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   1.4s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.934) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.932) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.932) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.947) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.932) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.947) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.932) total time=   1.4s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   1.5s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.654, test=0.646) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.401, test=0.400) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.654, test=0.646) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.771, test=0.774) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.401, test=0.400) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.654, test=0.646) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.771, test=0.774) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.401, test=0.400) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.654, test=0.646) total time=   1.4s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.771, test=0.774) total time=   1.3s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.401, test=0.400) total time=   1.4s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.670, test=0.660) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.371, test=0.371) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.668, test=0.670) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.670, test=0.660) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.371, test=0.371) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.668, test=0.670) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.670, test=0.660) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.371, test=0.371) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.668, test=0.670) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.670, test=0.660) total time=   1.3s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.371, test=0.371) total time=   1.3s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.668, test=0.670) total time=   1.4s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.735, test=0.715) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.727, test=0.725) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.212, test=0.213) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.735, test=0.715) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.727, test=0.725) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.212, test=0.213) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.735, test=0.715) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.727, test=0.725) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.212, test=0.213) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.735, test=0.715) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.727, test=0.725) total time=   1.5s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.212, test=0.213) total time=   1.5s

# %%
grid_model.best_params_
# Out:
# {'gamma': 0,
#  'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_child_weight': 1,
#  'n_estimators': 1000}

# %%
grid_model.best_score_
# Out:
# 0.948970495880744

# %%
# from sklearn.metrics import ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
# def evaluation_test(y,y_pred):
#     cm = confusion_matrix(y,y_pred)
#     disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
#     disp.plot()
#     plt.show()
#     n_classes = len(cm)
#     result = []
#     for c in range(n_classes):
#         tp = cm[c,c]
#         fp = sum(cm[:,c]) - cm[c,c]
#         fn = sum(cm[c,:]) - cm[c,c]
#         tn = sum(np.delete(sum(cm)-cm[c,:],c))
#         acc = (tp+tn) / (tp+fn+tn+fp)
#         recall = tp/(tp+fn)
#         precision = tp/(tp+fp)
#         specificity = tn/(tn+fp)
#         f1_score = 2*((precision*recall)/(precision+recall))
#         if c+1 == 1:
#             Rhythm = 'AFIB'
#         elif c+1 == 2:
#             Rhythm = 'SB'
#         elif c+1 == 3:
#             Rhythm = 'SR'
#         else:
#             Rhythm = 'GSVT'
#         result.append([Rhythm,acc,recall,precision,f1_score,specificity])
#     p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
#     p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
#     p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
#     result.append(['macro avg',None,r_macro,p_macro,f_macro,None])
#     result.append(['micro avg',None,r_micro,p_micro,f_micro,None])
#     result.append(['weighted avg',None,r_weighted,p_weighted,f_weighted,None])
#     return result

# %%
# evaluation_test = evaluation_test(y_test,result_test)
# df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","Recall","Precision","F1-score","specificity"])
# df_evaluation_test

# %%
# df_evaluation_test.to_csv("../Result/XGB_12_lead_test_mean.csv")
