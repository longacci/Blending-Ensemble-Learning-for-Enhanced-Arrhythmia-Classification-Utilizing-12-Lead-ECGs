# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
df_train = pd.read_csv("../data_train_fillna.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)
df_train
# Out:
#         0     1    2     3            4       5           6      7         8  \
# 0     0.0  52.0  0.0  10.0   918.222222   882.0   94.903200  310.0  0.472670
# 1     1.0  35.0  1.0   9.0  1138.500000  1145.0   22.555487   64.0 -0.461107
# 2     2.0  45.0  1.0  10.0   896.666667   944.0  204.320010  646.0 -1.350073
# 3     3.0  72.0  0.0  16.0   587.333333   588.0   22.623488  106.0 -1.644839
# 4     1.0  68.0  0.0   9.0  1035.000000  1032.0   31.336879   90.0  0.346377
# ...   ...   ...  ...   ...          ...     ...         ...    ...       ...
# 8511  2.0  53.0  0.0  11.0   914.200000   912.0   15.810123   52.0  0.592631
# 8512  1.0  78.0  1.0   8.0  1131.142857  1056.0  123.417328  282.0  0.939151
# 8513  3.0  71.0  1.0  15.0   612.000000   612.0    2.000000    6.0  0.857143
# 8514  3.0  28.0  1.0  20.0   488.105263   488.0    3.006917   12.0  0.003346
# 8515  3.0  41.0  0.0  20.0   474.842105   474.0    3.133237   14.0  0.187241
#
#              9  ...   233   234         235           236         237  \
# 0    -0.949065  ...  10.0   9.0  524.000000  11430.000000  147.250000
# 1    -1.286145  ...   8.0   8.0  469.000000   1016.000000  146.285714
# 2     0.489157  ...  11.0  10.0  478.400000   1852.640000  123.600000
# 3     4.250959  ...  12.0  11.0  395.142857   4358.693878   76.000000
# 4    -1.297847  ...   9.0   0.0  410.895810   2039.462769  122.920761
# ...        ...  ...   ...   ...         ...           ...         ...
# 8511 -0.592510  ...  11.0  10.0  423.555556    364.246914   62.444444
# 8512 -1.104222  ...   8.0   7.0  517.714286     70.204082  128.285714
# 8513 -0.285714  ...  15.0   1.0  394.000000      0.000000  156.000000
# 8514 -0.463470  ...  15.0  19.0  273.200000   1626.560000  130.421053
# 8515  0.047356  ...  19.0  18.0  321.555556   2834.913580  109.222222
#
#                238        239           240         241           242
# 0      3440.937500  71.250000   2477.937500  171.200000   1482.560000
# 1     10377.632653  55.500000  12749.750000  168.250000    461.437500
# 2      5864.640000  20.800000   7330.560000  124.909091   3343.537190
# 3      2091.000000 -40.000000   3449.142857   42.333333  11889.222222
# 4      3154.034717  21.669423   3522.522691  206.666667    552.888889
# ...            ...        ...           ...         ...           ...
# 8511    236.246914 -28.888889    295.209877  124.000000   2024.727273
# 8512  10653.061224  58.857143  11244.408163  175.500000    576.750000
# 8513      0.000000  86.000000      0.000000  130.133333     26.382222
# 8514    656.243767  57.684211   1234.216066  110.133333   1379.448889
# 8515   3185.395062  -1.777778   2341.728395   52.421053   2678.980609
#
# [8516 rows x 243 columns]

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
scale = MinMaxScaler()
x_train = scale.fit_transform(x_train)

# %%
df_test = pd.read_csv("../data_test_fillna.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)
df_test
# Out:
#         0     1    2     3            4       5           6      7         8  \
# 0     1.0  62.0  1.0   8.0  1170.571429  1168.0   16.273178   42.0  0.650965
# 1     3.0  74.0  1.0  18.0   533.647059   532.0    4.405093   12.0  0.290425
# 2     3.0  79.0  1.0  17.0   571.375000   573.0    5.372092   18.0 -0.962004
# 3     1.0  56.0  1.0   9.0  1038.000000  1039.0   19.442222   68.0 -0.563330
# 4     0.0  70.0  1.0  25.0   393.333333   392.0    3.248931   14.0  1.537888
# ...   ...   ...  ...   ...          ...     ...         ...    ...       ...
# 2125  1.0  64.0  0.0  10.0  1031.777778  1034.0   60.003292  248.0  0.096327
# 2126  2.0  67.0  1.0  13.0   722.166667   723.0    6.504272   22.0 -0.859445
# 2127  3.0  46.0  1.0  17.0   586.000000   586.0    6.855655   28.0 -0.046553
# 2128  0.0  69.0  1.0  10.0   918.222222   840.0  214.508108  684.0  1.333096
# 2129  3.0  38.0  0.0  16.0   592.800000   590.0   29.237419  108.0  0.272553
#
#              9  ...   233   234         235           236         237  \
# 0    -1.237999  ...   8.0   8.0  458.571429     24.816327  132.000000
# 1    -1.358307  ...  14.0  17.0  353.571429    952.673469  144.823529
# 2    -0.290856  ...  13.0  14.0  427.500000   1328.750000  102.714286
# 3     0.000420  ...   9.0   5.0  513.200000   2108.160000  110.400000
# 4     2.495402  ...   0.0  23.0  410.895810   2039.462769  122.920761
# ...        ...  ...   ...   ...         ...           ...         ...
# 2125  1.069329  ...   9.0   9.0  414.000000   1331.555556  108.888889
# 2126 -0.264470  ...  13.0  12.0  413.500000    389.416667  132.666667
# 2127 -0.258488  ...  16.0  16.0  412.875000    768.984375   57.500000
# 2128  0.602620  ...  10.0   5.0  370.000000  16614.000000  253.500000
# 2129 -0.573703  ...  16.0  15.0  367.733333   2697.528889   91.733333
#
#               238         239          240         241          242
# 0       43.428571   33.428571    62.530612  164.500000   235.750000
# 1      195.792388   40.352941   911.640138   69.000000   284.428571
# 2     1640.346939    1.714286  2415.918367  102.153846    69.207101
# 3     2899.840000  -31.600000  2002.240000  171.333333    49.777778
# 4     3154.034717   21.669423  3522.522691   99.852469  2078.683018
# ...           ...         ...          ...         ...          ...
# 2125  1453.432099   -4.444444  1383.802469   93.600000   135.040000
# 2126  2414.888889   76.666667  2498.888889  181.384615  2109.159763
# 2127  1077.250000  -41.625000   779.109375   44.800000  6084.693333
# 2128  2402.750000  158.000000  1650.000000  108.800000  4868.160000
# 2129   906.062222    0.133333   813.582222  130.250000  2168.437500
#
# [2130 rows x 243 columns]

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
x_test = scale.transform(x_test)

# %%
lr_clf = LogisticRegression(C= 1, max_iter= 200, penalty= 'l2', solver= 'sag')
rf_clf = RandomForestClassifier(criterion= 'entropy', max_depth= 5, max_features= 'sqrt', n_estimators= 100)
ab_clf = AdaBoostClassifier(algorithm= 'SAMME', learning_rate= 0.1, n_estimators= 1000)
knn_clf = KNeighborsClassifier(algorithm= 'auto', n_neighbors= 6, p= 1, weights= 'uniform')
svc_clf = SVC(C= 10, gamma= 'scale', kernel= 'rbf', probability= True)
xgb_clf = XGBClassifier(gamma= 0.1,learning_rate= 0.1,max_depth= 3,min_child_weight= 1,n_estimators= 1000)
dt_clf = DecisionTreeClassifier(criterion= 'gini',max_depth= 5,max_features= 'sqrt',splitter= 'best')

# %%
# Huấn luyện các mô hình con
lr_clf.fit(x_train,y_train)
rf_clf.fit(x_train,y_train)
ab_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
svc_clf.fit(x_train, y_train)
# xgb_clf.fit(x_train, y_train)
dt_clf.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# DecisionTreeClassifier(max_depth=5, max_features='sqrt')

# %%
# Dự đoán trên tập huấn luyện để tạo đặc trưng mới cho mô hình blending
X_train_meta = np.column_stack((
    lr_clf.predict_proba(x_train),
    rf_clf.predict_proba(x_train),
    ab_clf.predict_proba(x_train),
    knn_clf.predict_proba(x_train),
    svc_clf.predict_proba(x_train),
    # xgb_clf.predict_proba(x_train),
    dt_clf.predict_proba(x_train)
))
# Dự đoán trên tập kiểm tra để tạo đặc trưng mới cho mô hình blending
X_test_meta = np.column_stack((
    lr_clf.predict_proba(x_test),
    rf_clf.predict_proba(x_test),
    ab_clf.predict_proba(x_test),
    knn_clf.predict_proba(x_test),
    svc_clf.predict_proba(x_test),
    # xgb_clf.predict_proba(x_test),
    dt_clf.predict_proba(x_test)
))

# %%
print(f"X_train_meta:{X_train_meta.shape}")
print(f"X_test_meta:{X_test_meta.shape}")
# Out:
# X_train_meta:(8516, 24)
# X_test_meta:(2130, 24)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
model = XGBClassifier()
params = {
    'n_estimators': [10,50,100,1000],
    'learning_rate': [0.01,0.1,1,10],
    'max_depth': [3,4,5],
    'min_child_weight':[1],
    'gamma':[0,0.1,0.2],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X_train_meta,y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.982) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.970) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.982, test=0.981) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.970) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.982) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.981, test=0.982) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.971) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.993, test=0.984) total time=   2.9s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.987) total time=   3.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.977) total time=   3.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.971) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.985, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.972) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.982) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.983) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.971) total time=   0.3s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.986) total time=   3.5s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.985) total time=   3.6s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.978) total time=   3.7s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.983) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.972) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.982) total time=   0.4s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.984) total time=   0.4s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.972) total time=   0.4s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   4.5s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.986) total time=   4.4s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.979) total time=   4.4s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.971) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.984) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.973) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.993, test=0.984) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.987) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.995, test=0.977) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   2.6s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   2.5s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   2.6s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.984) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.988, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.986) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.993, test=0.975) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.985) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.986) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.978) total time=   0.3s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.984) total time=   2.8s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   2.8s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   2.9s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.988, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.973) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.985) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.985) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.976) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.3s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.986) total time=   0.4s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.979) total time=   0.4s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   3.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.987) total time=   3.2s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   2.7s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.986) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.975) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.982) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.987) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.978) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   1.8s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   1.9s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.979) total time=   1.8s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.983) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.986) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.984) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.986) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.977) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.9s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   2.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.979) total time=   1.9s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.975) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.987) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.987) total time=   0.2s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.976) total time=   0.2s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.9s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.987) total time=   1.8s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.978) total time=   1.9s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.219, test=0.217) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.909, test=0.891) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.219, test=0.217) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.909, test=0.891) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.012, test=0.010) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.219, test=0.217) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.909, test=0.891) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.012, test=0.010) total time=   1.6s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.219, test=0.217) total time=   1.4s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.909, test=0.891) total time=   1.7s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.278, test=0.283) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.634, test=0.638) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.278, test=0.283) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.634, test=0.638) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.278, test=0.283) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.018, test=0.015) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.634, test=0.638) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.278, test=0.283) total time=   1.7s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.018, test=0.015) total time=   1.4s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.634, test=0.638) total time=   1.8s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.537, test=0.524) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.528, test=0.542) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.400, test=0.390) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.537, test=0.524) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.528, test=0.542) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.400, test=0.390) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.537, test=0.524) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.528, test=0.542) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.400, test=0.390) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.537, test=0.524) total time=   1.6s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.528, test=0.542) total time=   1.7s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.400, test=0.390) total time=   1.7s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.982) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.970) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.982, test=0.981) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.970) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.982) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.981, test=0.982) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.972) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.993, test=0.984) total time=   2.9s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.987) total time=   3.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.977) total time=   3.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.985, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.972) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.982) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.983) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.972) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.986) total time=   3.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.985) total time=   3.8s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.978) total time=   3.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.971) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.983) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.973) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.982) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.989, test=0.983) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.973) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.984) total time=   4.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.986) total time=   4.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.979) total time=   4.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.984) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.986) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.973) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.993, test=0.984) total time=   0.2s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.987) total time=   0.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.977) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   1.7s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   1.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.976) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.984) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.988, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.993, test=0.975) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.986) total time=   0.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.985) total time=   0.3s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.978) total time=   0.3s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.984) total time=   1.7s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.978) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.984) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.973) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.985) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.986) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.975) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.986) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.977) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.984) total time=   1.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   1.7s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.979) total time=   1.7s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.975) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.984) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.976) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.984) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.984) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.3s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.976) total time=   1.3s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.985) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.983) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.976) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.3s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.976) total time=   1.3s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.975) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.986) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.980) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.986) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.980) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.986) total time=   1.3s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   1.3s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.412, test=0.413) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.916, test=0.895) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.412, test=0.413) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.916, test=0.895) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.012, test=0.010) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.412, test=0.413) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.916, test=0.895) total time=   0.2s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.012, test=0.010) total time=   1.5s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.412, test=0.413) total time=   1.8s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.916, test=0.895) total time=   1.7s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.278, test=0.283) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.634, test=0.638) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.278, test=0.283) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.634, test=0.638) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.278, test=0.283) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.018, test=0.015) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.634, test=0.638) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.278, test=0.283) total time=   1.7s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.018, test=0.015) total time=   1.4s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.634, test=0.638) total time=   1.6s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.537, test=0.524) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.217, test=0.220) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.668, test=0.656) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.537, test=0.524) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.217, test=0.220) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.668, test=0.656) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.537, test=0.524) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.217, test=0.220) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.668, test=0.656) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.537, test=0.524) total time=   1.5s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.217, test=0.220) total time=   1.6s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.668, test=0.656) total time=   1.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.982, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.979, test=0.982) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.970) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.982, test=0.981) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.970) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.982) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.981, test=0.982) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.972) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.993, test=0.984) total time=   2.7s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.987) total time=   2.7s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.977) total time=   2.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.985, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.983) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.972) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.982) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.986, test=0.983) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.971) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.986) total time=   3.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.985) total time=   3.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.979) total time=   3.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.980) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.971) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.988, test=0.983) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.989, test=0.973) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.982) total time=   0.4s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.988, test=0.984) total time=   0.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.990, test=0.973) total time=   0.4s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.983) total time=   3.8s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.986) total time=   3.8s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.978) total time=   3.9s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.981, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.984, test=0.972) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.984) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.986, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.987, test=0.973) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.993, test=0.983) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.986) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.977) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.984) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.987) total time=   1.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.977) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.986, test=0.983) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.971) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.990, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.993, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.986) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.986) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.978) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.984) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.986) total time=   1.5s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.978) total time=   1.5s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.981) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.984) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.974) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.985) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.974) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.984) total time=   0.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.986) total time=   0.3s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.978) total time=   0.3s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.984) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.986) total time=   1.5s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.978) total time=   1.4s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.975) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.983) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.983) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.983) total time=   1.2s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.2s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   1.4s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.998, test=0.984) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.986) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.999, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.976) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.982) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.976) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.982) total time=   1.2s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.2s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.976) total time=   1.2s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=1.000, test=0.978) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.982) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.985) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.977) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.982) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.985) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.977) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.982) total time=   1.3s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.985) total time=   1.2s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.977) total time=   1.2s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.412, test=0.413) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.916, test=0.895) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.012, test=0.010) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.412, test=0.413) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.916, test=0.895) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.012, test=0.010) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.412, test=0.413) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.916, test=0.895) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.012, test=0.010) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.412, test=0.413) total time=   1.6s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.916, test=0.895) total time=   1.6s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.012, test=0.008) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.698, test=0.697) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.012, test=0.008) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.018, test=0.015) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.698, test=0.697) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.012, test=0.008) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.018, test=0.015) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.698, test=0.697) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.012, test=0.008) total time=   1.5s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.018, test=0.015) total time=   1.4s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.698, test=0.697) total time=   1.6s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.494, test=0.494) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.217, test=0.220) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.677, test=0.654) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.494, test=0.494) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.217, test=0.220) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.677, test=0.654) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.494, test=0.494) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.217, test=0.220) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.677, test=0.654) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.494, test=0.494) total time=   1.6s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.217, test=0.220) total time=   1.6s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.677, test=0.654) total time=   1.7s

# %%
result_test = grid_model.predict(X_test_meta)

# %%
grid_model.best_params_
# Out:
# {'gamma': 0,
#  'learning_rate': 1,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'n_estimators': 1000}

# %%
grid_model.best_score_
# Out:
# 0.983207609570479

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,f_macro,p_macro,r_macro,None])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,None])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC  F1-score  Precision    Recall  specificity
# 0          AFIB  0.962911  0.916854   0.906667  0.911732     0.975074
# 1            SB  0.990610  0.991003   0.983418  0.987196     0.990385
# 2            SR  0.983099  0.957303   0.961625  0.959459     0.989911
# 3          GSVT  0.964789  0.909091   0.927152  0.918033     0.980216
# 4     macro avg       NaN  0.944105   0.944716  0.943563          NaN
# 5     micro avg       NaN  0.950704   0.950704  0.950704          NaN
# 6  weighted avg       NaN  0.950634   0.950626  0.950704          NaN

# %%
# df_evaluation_test.to_csv("../Result/Blending_XGB.csv")
