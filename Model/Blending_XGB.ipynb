# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
df_train = pd.read_csv("../data_train_125ft.csv")
df_train.drop(columns=["Unnamed: 0"],inplace=True)
df_train
# Out:
#         0     1    2     3            4       5           6      7         8  \
# 0     0.0  87.0  1.0  14.0   712.000000   696.0   65.440519  240.0  0.703359
# 1     2.0  49.0  1.0  13.0   712.000000   691.0   47.300458  158.0  0.884010
# 2     1.0  86.0  1.0   9.0  1096.250000  1098.0    8.150920   28.0 -0.156675
# 3     1.0  70.0  1.0   8.0  1169.714286  1168.0    4.463000   14.0  0.642283
# 4     3.0  61.0  0.0  16.0   585.333333   586.0    2.890598   12.0  0.196283
# ...   ...   ...  ...   ...          ...     ...         ...    ...       ...
# 8343  0.0  72.0  1.0  16.0   619.466667   592.0  139.659522  480.0  0.480046
# 8344  3.0  23.0  0.0  19.0   510.777778   512.0    7.091118   30.0 -0.059891
# 8345  1.0  51.0  0.0   9.0  1090.250000  1088.0    9.769212   30.0  0.213875
# 8346  3.0  45.0  0.0  26.0   370.320000   370.0    3.133305   10.0  0.358316
# 8347  1.0  28.0  1.0   9.0  1037.000000  1037.0   28.372522   94.0 -0.267952
#
#              9  ...          114     115         116    117       118  \
# 0    -0.246387  ...   712.000000   696.0   65.707979  240.0  0.699256
# 1    -0.332635  ...   712.000000   691.0   47.483330  156.0  0.894198
# 2    -0.642487  ...  1096.000000  1098.0    8.426150   28.0 -0.160466
# 3    -0.722722  ...  1169.428571  1168.0    4.237828   14.0  0.827427
# 4     0.113400  ...   585.333333   586.0    3.155243   12.0  0.354663
# ...        ...  ...          ...     ...         ...    ...       ...
# 8343 -0.842798  ...   619.466667   594.0  139.562109  482.0  0.472791
# 8344 -0.269851  ...   510.888889   512.0    6.870944   28.0  0.081059
# 8345 -1.152589  ...  1090.250000  1088.0    8.742854   28.0  0.436427
# 8346 -0.885061  ...   370.400000   370.0    3.098387   12.0  0.051640
# 8347 -0.810638  ...  1037.000000  1037.0   28.705400   94.0 -0.237050
#
#            119          120       121   122   123
# 0    -0.277091   783.821985  0.785714   9.0   6.0
# 1    -0.355280   380.188159  1.000000  13.0  12.0
# 2    -0.801230   808.359965  1.000000   8.0   6.0
# 3    -0.140248  1150.133430  1.000000   8.0   7.0
# 4    -0.484056   198.042444  1.000000  16.0  15.0
# ...        ...          ...       ...   ...   ...
# 8343 -0.825913   468.155165  1.000000  16.0   8.0
# 8344 -0.433829   309.210006  1.000000  19.0  18.0
# 8345 -0.891096   940.155678  1.000000   9.0   8.0
# 8346 -0.703333   856.813033  0.461538   1.0   6.0
# 8347 -0.876580   495.494523  1.000000   9.0   8.0
#
# [8348 rows x 124 columns]

# %%
x_train = df_train.iloc[:,1:].values
y_train = df_train.iloc[:,0].values

# %%
scale = MinMaxScaler()
x_train = scale.fit_transform(x_train)

# %%
df_test = pd.read_csv("../data_test_125ft.csv")
df_test.drop(columns=["Unnamed: 0"],inplace=True)
df_test
# Out:
#         0     1    2     3            4       5           6      7         8  \
# 0     1.0  32.0  0.0   9.0  1091.750000  1091.0   22.280877   66.0  0.493022
# 1     1.0  17.0  0.0   9.0  1115.000000  1106.0   59.841457  186.0  0.777480
# 2     2.0  64.0  0.0  12.0   806.000000   804.0    8.045326   30.0  0.293282
# 3     3.0  61.0  0.0  21.0   458.300000   458.0    1.705872    6.0  0.192180
# 4     1.0  70.0  1.0  10.0   941.555556  1054.0  220.140920  628.0 -1.482314
# ...   ...   ...  ...   ...          ...     ...         ...    ...       ...
# 2083  3.0  71.0  0.0  20.0   485.789474   486.0    3.104817   10.0 -0.415255
# 2084  1.0  51.0  1.0   9.0  1060.250000  1056.0   14.677789   44.0  0.273677
# 2085  1.0  61.0  1.0   9.0  1070.250000  1076.0   33.082284   98.0 -0.016678
# 2086  1.0  74.0  1.0   9.0  1021.750000  1018.0    7.171994   22.0  0.898849
# 2087  1.0  63.0  0.0   9.0  1079.500000  1089.0   20.826666   54.0 -0.460865
#
#              9  ...          114     115        116    117       118  \
# 0    -0.931472  ...  1092.000000  1091.0  22.000000   66.0  0.521225
# 1    -0.423745  ...  1115.000000  1107.0  60.728906  192.0  0.772436
# 2    -0.392690  ...   806.000000   804.0   7.722458   26.0  0.198976
# 3    -0.770964  ...   458.300000   458.0   1.926136    6.0  0.368600
# 4     0.419095  ...  1059.250000  1059.0  10.341059   34.0 -0.061463
# ...        ...  ...          ...     ...        ...    ...       ...
# 2083 -0.874744  ...   485.789474   486.0   2.966106   10.0 -0.496663
# 2084 -1.204916  ...  1060.250000  1056.0  13.872184   40.0  0.231747
# 2085 -1.320021  ...  1070.250000  1075.0  32.686962   96.0  0.030170
# 2086 -0.581729  ...  1021.750000  1020.0   7.101936   24.0  0.839867
# 2087 -1.486785  ...  1079.750000  1087.0  21.574001   60.0 -0.405116
#
#            119         120  121   122   123
# 0    -0.913087  373.995302  1.0   9.0   7.0
# 1    -0.395166  477.271172  1.0   9.0   8.0
# 2    -0.896193  277.972651  1.0  12.0  11.0
# 3    -0.876527  361.998395  1.0   0.0  20.0
# 4    -0.843856  586.261896  1.0   9.0   7.0
# ...        ...         ...  ...   ...   ...
# 2083 -0.494835  798.662084  1.0  10.0  19.0
# 2084 -1.352375  603.272611  1.0   9.0   8.0
# 2085 -1.329810  692.057509  1.0   9.0   4.0
# 2086 -0.281413  456.052143  1.0   9.0   8.0
# 2087 -1.328357  324.178086  1.0   9.0   8.0
#
# [2088 rows x 124 columns]

# %%
x_test = df_test.iloc[:,1:].values
y_test = df_test.iloc[:,0].values

# %%
x_test = scale.transform(x_test)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train , test_size=0.5, shuffle=True, stratify=y_train, random_state=119)
print(f"Train: {x_train.shape}")
print(f"Vallidation: {x_val.shape}")
# Out:
# Train: (4174, 123)
# Vallidation: (4174, 123)

# %%
rf_clf = RandomForestClassifier(criterion= 'log_loss', max_depth= 5, max_features= 'sqrt', n_estimators= 1000)
ab_clf = AdaBoostClassifier(algorithm= 'SAMME.R', learning_rate= 0.1, n_estimators= 50)
knn_clf = KNeighborsClassifier(algorithm= 'auto', n_neighbors= 5, p= 1, weights= 'uniform')
svc_clf = SVC(C= 100, gamma= 'scale', kernel= 'rbf', probability= True)
# xgb_clf = XGBClassifier(gamma= 0,learning_rate= 0.1,max_depth= 5,min_child_weight= 1,n_estimators= 1000)
dt_clf = DecisionTreeClassifier(criterion= 'entropy',max_depth= 5,max_features= 'sqrt',splitter= 'best')

# %%
# Huấn luyện các mô hình con
rf_clf.fit(x_train,y_train)
ab_clf.fit(x_train, y_train)
knn_clf.fit(x_train, y_train)
svc_clf.fit(x_train, y_train)
# xgb_clf.fit(x_train, y_train)
dt_clf.fit(x_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# DecisionTreeClassifier(criterion='entropy', max_depth=5, max_features='sqrt')

# %%
# Dự đoán trên tập huấn luyện để tạo đặc trưng mới cho mô hình blending
X_train_meta = np.column_stack((
    rf_clf.predict_proba(x_val),
    ab_clf.predict_proba(x_val),
    knn_clf.predict_proba(x_val),
    svc_clf.predict_proba(x_val),
    # xgb_clf.predict_proba(x_val),
    dt_clf.predict_proba(x_val)
))
# Dự đoán trên tập kiểm tra để tạo đặc trưng mới cho mô hình blending
X_test_meta = np.column_stack((
    rf_clf.predict_proba(x_test),
    ab_clf.predict_proba(x_test),
    knn_clf.predict_proba(x_test),
    svc_clf.predict_proba(x_test),
    # xgb_clf.predict_proba(x_test),
    dt_clf.predict_proba(x_test)
))

# %%
print(f"X_train_meta:{X_train_meta.shape}")
print(f"X_test_meta:{X_test_meta.shape}")
# Out:
# X_train_meta:(4174, 20)
# X_test_meta:(2088, 20)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
model = XGBClassifier()
params = {
    'n_estimators': [10,50,100,1000],
    'learning_rate': [0.01,0.1,1,10],
    'max_depth': [3,4,5],
    'min_child_weight':[1],
    'gamma':[0,0.1,0.2],
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X_train_meta,y_val)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.955, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.956, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.960, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.958, test=0.942) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.969, test=0.936) total time=   1.3s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.966, test=0.947) total time=   1.3s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.968, test=0.942) total time=   1.4s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.963, test=0.948) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.966, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.965, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.965, test=0.941) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.964, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.983, test=0.938) total time=   1.9s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.982, test=0.950) total time=   2.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.982, test=0.942) total time=   2.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.969, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.971, test=0.939) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.972, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.944) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.973, test=0.943) total time=   0.2s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.973, test=0.949) total time=   0.3s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.971, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.995, test=0.937) total time=   1.6s
# [CV 2/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.993, test=0.949) total time=   1.9s
# [CV 3/3] END gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.995, test=0.942) total time=   2.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.962, test=0.943) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.961, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.963, test=0.947) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.970, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   1.1s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.944) total time=   1.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   1.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.967, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.973, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.972, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.969, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.983, test=0.936) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.936) total time=   1.2s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   1.3s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   1.2s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.938) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.949) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.938) total time=   1.3s
# [CV 2/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.947) total time=   1.3s
# [CV 3/3] END gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   1.4s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.975, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.941) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.943) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.938) total time=   1.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.940) total time=   0.9s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   0.8s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.987, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.948) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.931) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.929) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.940) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.931) total time=   0.9s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.941) total time=   0.9s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.943) total time=   0.9s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.997, test=0.939) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.997, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.938) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.939) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.938) total time=   0.1s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.943) total time=   0.1s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.1s
# [CV 1/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.938) total time=   0.8s
# [CV 2/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   1.0s
# [CV 3/3] END gamma=0, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.943) total time=   0.8s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.024, test=0.020) total time=   0.5s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.027, test=0.032) total time=   0.6s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.034, test=0.036) total time=   0.8s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.022, test=0.020) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.333, test=0.332) total time=   0.6s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.013, test=0.018) total time=   0.7s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.876, test=0.877) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.876, test=0.877) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.876, test=0.877) total time=   0.0s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.876, test=0.877) total time=   0.6s
# [CV 2/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.023, test=0.021) total time=   0.5s
# [CV 3/3] END gamma=0, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.030, test=0.032) total time=   0.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.955, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.956, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.960, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.958, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.969, test=0.936) total time=   1.3s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.966, test=0.947) total time=   1.2s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.968, test=0.942) total time=   1.2s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.963, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.966, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.965, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.965, test=0.941) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.964, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.983, test=0.938) total time=   1.8s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.981, test=0.949) total time=   1.7s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.983, test=0.943) total time=   1.5s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.972, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.943) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.972, test=0.943) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.974, test=0.949) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.971, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.938) total time=   2.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.993, test=0.950) total time=   1.9s
# [CV 3/3] END gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.944) total time=   2.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.962, test=0.943) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.961, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.963, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.969, test=0.940) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.967, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.967, test=0.945) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.935) total time=   0.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.948) total time=   0.7s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.942) total time=   0.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.967, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.943) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.973, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.972, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.969, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.938) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.949) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.983, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.938) total time=   0.6s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.995, test=0.951) total time=   0.6s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.996, test=0.942) total time=   0.6s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.946) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.974, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.984, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.982, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.995, test=0.938) total time=   0.1s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.996, test=0.942) total time=   0.8s
# [CV 2/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.948) total time=   0.9s
# [CV 3/3] END gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.942) total time=   0.7s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.975, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.935) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   0.6s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.990, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.944) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.935) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.944) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.935) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.944) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.945) total time=   0.5s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.937) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.941) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=1.000, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.941) total time=   0.4s
# [CV 2/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   0.4s
# [CV 3/3] END gamma=0.1, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=1.000, test=0.942) total time=   0.4s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.024, test=0.020) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.027, test=0.032) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.034, test=0.036) total time=   0.6s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.013, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.022, test=0.020) total time=   0.5s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.333, test=0.332) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.013, test=0.018) total time=   0.6s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.031, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.031, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.023, test=0.021) total time=   0.0s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.031, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.375, test=0.378) total time=   0.6s
# [CV 2/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.023, test=0.021) total time=   0.5s
# [CV 3/3] END gamma=0.1, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.031, test=0.032) total time=   0.6s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.955, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.956, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.959, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.956, test=0.941) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.960, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.958, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.959, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.962, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.970, test=0.937) total time=   1.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.966, test=0.947) total time=   1.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.968, test=0.943) total time=   1.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.945) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.950) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.963, test=0.948) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.964, test=0.942) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.966, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.965, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.965, test=0.941) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.948) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.964, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.983, test=0.939) total time=   1.3s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.981, test=0.950) total time=   1.4s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.982, test=0.943) total time=   1.7s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.968, test=0.946) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.937) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.969, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.972, test=0.942) total time=   0.2s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.974, test=0.948) total time=   0.2s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.970, test=0.942) total time=   0.2s
# [CV 1/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.938) total time=   2.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.950) total time=   1.8s
# [CV 3/3] END gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.942) total time=   1.9s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.958, test=0.944) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.958, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.961, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.962, test=0.943) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.961, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.962, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.970, test=0.937) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.967, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.968, test=0.944) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.979, test=0.936) total time=   0.8s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.981, test=0.948) total time=   0.6s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.978, test=0.940) total time=   0.8s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.965, test=0.943) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.967, test=0.949) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.964, test=0.943) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.973, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.972, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.970, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.982, test=0.935) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.984, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.983, test=0.943) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.985, test=0.937) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.989, test=0.950) total time=   0.7s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.986, test=0.942) total time=   0.8s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.972, test=0.946) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.947) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.970, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.983, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.981, test=0.943) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.937) total time=   0.1s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.992, test=0.950) total time=   0.1s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.942) total time=   0.1s
# [CV 1/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.936) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.992, test=0.949) total time=   0.8s
# [CV 3/3] END gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.942) total time=   0.7s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.973, test=0.939) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.971, test=0.948) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.991, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.995, test=0.943) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.939) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.991, test=0.933) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.995, test=0.943) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.997, test=0.939) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.991, test=0.933) total time=   0.5s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.995, test=0.943) total time=   0.5s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.997, test=0.939) total time=   1.2s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.988, test=0.940) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.988, test=0.944) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.989, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.994, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.999, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.994, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.999, test=0.945) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.996, test=0.938) total time=   0.6s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.994, test=0.942) total time=   0.6s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.999, test=0.945) total time=   0.5s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.997, test=0.937) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.996, test=0.941) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.995, test=0.942) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.997, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.996, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.998, test=0.940) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.997, test=0.938) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.996, test=0.942) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.998, test=0.940) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.997, test=0.938) total time=   0.6s
# [CV 2/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.996, test=0.942) total time=   0.5s
# [CV 3/3] END gamma=0.2, learning_rate=1, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.998, test=0.940) total time=   0.6s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=10;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=50;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.024, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.027, test=0.032) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=100;, score=(train=0.034, test=0.036) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.024, test=0.020) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.027, test=0.032) total time=   0.6s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=3, min_child_weight=1, n_estimators=1000;, score=(train=0.034, test=0.036) total time=   0.7s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=10;, score=(train=0.012, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=50;, score=(train=0.012, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.022, test=0.020) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.333, test=0.332) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=100;, score=(train=0.012, test=0.018) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.022, test=0.020) total time=   0.5s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.333, test=0.332) total time=   0.6s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=4, min_child_weight=1, n_estimators=1000;, score=(train=0.012, test=0.018) total time=   0.7s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.022, test=0.019) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=10;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.022, test=0.019) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=50;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.375, test=0.378) total time=   0.0s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.022, test=0.019) total time=   0.0s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=100;, score=(train=0.030, test=0.032) total time=   0.0s
# [CV 1/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.375, test=0.378) total time=   0.7s
# [CV 2/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.022, test=0.019) total time=   0.5s
# [CV 3/3] END gamma=0.2, learning_rate=10, max_depth=5, min_child_weight=1, n_estimators=1000;, score=(train=0.030, test=0.032) total time=   0.5s

# %%
result_test = grid_model.predict(X_test_meta)

# %%
grid_model.best_params_
# Out:
# {'gamma': 0,
#  'learning_rate': 0.01,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'n_estimators': 10}

# %%
grid_model.best_score_
# Out:
# 0.9472933899094066

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,multilabel_confusion_matrix,f1_score,precision_score,accuracy_score,recall_score,precision_recall_fscore_support
def evaluation_test(y,y_pred):
    cm = confusion_matrix(y,y_pred)
    disp = ConfusionMatrixDisplay(cm,display_labels=['AFIB','SB','SR','GSVT'])
    disp.plot()
    plt.show()
    n_classes = len(cm)
    result = []
    for c in range(n_classes):
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc = (tp+tn) / (tp+fn+tn+fp)
        recall = tp/(tp+fn)
        precision = tp/(tp+fp)
        specificity = tn/(tn+fp)
        f1_score = 2*((precision*recall)/(precision+recall))
        if c+1 == 1:
            Rhythm = 'AFIB'
        elif c+1 == 2:
            Rhythm = 'SB'
        elif c+1 == 3:
            Rhythm = 'SR'
        else:
            Rhythm = 'GSVT'
        result.append([Rhythm,acc,recall,precision,f1_score,specificity])
    p_macro,r_macro,f_macro,support_macro = precision_recall_fscore_support(y,y_pred,average='macro')
    p_micro,r_micro,f_micro,support_micro = precision_recall_fscore_support(y,y_pred,average='micro')
    p_weighted,r_weighted,f_weighted,support_weighted = precision_recall_fscore_support(y,y_pred,average='weighted')
    result.append(['macro avg',None,f_macro,p_macro,r_macro,None])
    result.append(['micro avg',None,f_micro,p_micro,r_micro,None])
    result.append(['weighted avg',None,f_weighted,p_weighted,r_weighted,None])
    return result

# %%
evaluation_test = evaluation_test(y_test,result_test)
df_evaluation_test = pd.DataFrame(data=evaluation_test,columns=["Rhythm Group","ACC","F1-score","Precision","Recall","specificity"])
df_evaluation_test
# Out:
#    Rhythm Group       ACC  F1-score  Precision    Recall  specificity
# 0          AFIB  0.959291  0.892202   0.911007  0.901506     0.976998
# 1            SB  0.989943  0.984516   0.988342  0.986425     0.993145
# 2            SR  0.980843  0.963964   0.946903  0.955357     0.985401
# 3          GSVT  0.968391  0.928406   0.919908  0.924138     0.978852
# 4     macro avg       NaN  0.941857   0.941540  0.942272          NaN
# 5     micro avg       NaN  0.949234   0.949234  0.949234          NaN
# 6  weighted avg       NaN  0.949170   0.949190  0.949234          NaN

# %%
df_evaluation_test.to_csv("../Result/Blending_XGB_125ft.csv")
