# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../df_new_mean_train.csv")
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#         0     1    2            3             4            5             6  \
# 0     3.0  58.0  1.0   450.600000      1.640000   450.600000    526.440000
# 1     3.0  41.0  0.0   357.000000      1.923077   357.076923    538.840237
# 2     3.0  76.0  0.0   478.105263      1.041551   479.052632    345.839335
# 3     3.0  27.0  1.0   587.066667    357.262222   587.866667    663.182222
# 4     2.0  76.0  0.0   900.600000     95.240000   900.600000    170.440000
# ...   ...   ...  ...          ...           ...          ...           ...
# 8479  0.0  64.0  0.0   612.800000  29298.560000   611.733333  28027.128889
# 8480  3.0  75.0  0.0   418.956522   2734.563327   418.956522   2523.780718
# 8481  1.0  58.0  1.0  1235.428571    700.244898  1235.714286    897.632653
# 8482  2.0  75.0  1.0   823.800000   4775.560000   824.000000   4056.000000
# 8483  1.0  66.0  1.0  1100.000000   3967.000000  1095.500000   6184.750000
#
#                 7             8          9  ...            245       246  \
# 0      446.500000   5097.950000  -8.700000  ...   80062.392773  0.670011
# 1      356.076923  11891.224852  -1.307692  ...   76406.068692  0.850813
# 2      478.210526   2771.745152   0.315789  ...   85871.392384  0.489407
# 3      584.533333   6410.382222  -0.800000  ...  103785.759900  1.091541
# 4      905.000000  10025.000000   2.800000  ...   81079.175405  0.800294
# ...           ...           ...        ...  ...            ...       ...
# 8479   614.933333  28417.528889  -5.866667  ...  100877.375033  0.305497
# 8480   419.478261   8352.075614  -3.565217  ...   81455.005289  0.448115
# 8481  1248.285714  15626.775510  16.857143  ...   81763.393500  0.092227
# 8482   804.000000  11132.800000 -22.600000  ...   66478.783260  1.024300
# 8483  1091.000000   5050.000000 -16.250000  ...   55993.608000  0.410091
#
#            247       248          249   250   251   252         253        254
# 0    -0.912051  0.018315   242.648806  21.0  21.0  21.0   -1.714518   3.600000
# 1    -0.498918 -0.076761   974.391877  27.0  27.0  27.0    8.932387  -1.307692
# 2    -0.973497  0.262626    25.275439  20.0  20.0  20.0    6.346053   0.526316
# 3    -0.392591 -0.159420     9.601546  16.0  16.0  16.0   11.755690  -0.666667
# 4    -0.779998 -0.343434    11.737973  11.0  11.0  11.0 -143.141574   2.800000
# ...        ...       ...          ...   ...   ...   ...         ...        ...
# 8479 -1.525075 -0.201948  2438.340543  15.0  15.0  15.0   24.802373   8.571429
# 8480 -1.260327  0.309823    32.322927  24.0  24.0  24.0    5.947163  -3.565217
# 8481 -1.692873  0.599331    10.950366   8.0   8.0   8.0   18.149394  18.571429
# 8482 -0.596278  0.147300   335.316688  11.0  11.0  11.0    4.484999 -20.400000
# 8483 -1.525947 -0.070707    76.835189   8.0   8.0   8.0    4.645446 -18.285714
#
# [8484 rows x 255 columns]

# %%
x_train = df.iloc[:,1:].values
y_train = df.iloc[:,0].values

# %%
X = x_train
y = y_train

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)

# %%
from sklearn.metrics import confusion_matrix
def confusion_matrix_scorer(clf=None,X=None, y=None,y_pred=None,y_prob=None):
    if clf != None:
        y_pred = clf.predict(X)
        y_prob = clf.predict_proba(X)[:,1]
    cm = confusion_matrix(y,y_pred)
    acc_arr = []
    precision_arr = []
    recall_arr = []
    specificity_arr = []
    f1_arr = []
    for c in range(0,len(cm)):
        c = len(cm)-1
        tp = cm[c,c]
        fp = sum(cm[:,c]) - cm[c,c]
        fn = sum(cm[c,:]) - cm[c,c]
        tn = sum(np.delete(sum(cm)-cm[c,:],c))
        acc_arr.append((tp+tn) / (tp+fn+tn+fp))
        recall_arr.append(tp/(tp+fn))
        precision_arr.append(tp/(tp+fp))
        specificity_arr.append(tn/(tn+fp))
        f1_arr.append(2*(((tp/(tp+fp))*(tp/(tp+fn)))/((tp/(tp+fp))+(tp/(tp+fn)))))
    return {'acc':np.nanmean(acc_arr),'precision':np.nanmean(precision_arr),'specificity':np.nanmean(specificity_arr),'recall':np.nanmean(recall_arr),'f1_score':np.nanmean(f1_arr)}

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
model = DecisionTreeClassifier()
params = {
    'criterion':['gini', 'entropy', 'log_loss'],
    'max_depth': [3,4,5],
    'splitter':['best', 'random'],
    'max_features':['auto', 'sqrt', 'log2']
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X,y)
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV 1/3] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.883, test=0.867) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.857, test=0.862) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.800, test=0.786) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.728, test=0.737) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.624, test=0.617) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.697, test=0.698) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=(train=0.794, test=0.779) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=(train=0.791, test=0.792) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=log2, splitter=best;, score=(train=0.763, test=0.755) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=(train=0.418, test=0.414) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=(train=0.665, test=0.662) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=3, max_features=log2, splitter=random;, score=(train=0.572, test=0.570) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.905, test=0.897) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.884, test=0.881) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.908, test=0.898) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.765, test=0.759) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.749, test=0.747) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.693, test=0.693) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.866, test=0.849) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.892, test=0.886) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=best;, score=(train=0.890, test=0.891) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.671, test=0.650) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.688, test=0.693) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=4, max_features=log2, splitter=random;, score=(train=0.625, test=0.626) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.919, test=0.902) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.916, test=0.900) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.920, test=0.912) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.805, test=0.800) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.762, test=0.765) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.745, test=0.747) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.900, test=0.896) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.914, test=0.906) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=best;, score=(train=0.847, test=0.831) total time=   0.0s
# [CV 1/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.678, test=0.679) total time=   0.0s
# [CV 2/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.727, test=0.727) total time=   0.0s
# [CV 3/3] END criterion=gini, max_depth=5, max_features=log2, splitter=random;, score=(train=0.525, test=0.516) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.888, test=0.869) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.847, test=0.838) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.889, test=0.883) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.720, test=0.717) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.589, test=0.575) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.586, test=0.585) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=(train=0.892, test=0.873) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=(train=0.865, test=0.865) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=best;, score=(train=0.842, test=0.839) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=(train=0.676, test=0.676) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=(train=0.589, test=0.576) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=3, max_features=log2, splitter=random;, score=(train=0.696, test=0.692) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.906, test=0.893) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.894, test=0.889) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.883, test=0.870) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.669, test=0.662) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.761, test=0.761) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.798, test=0.797) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.906, test=0.894) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.825, test=0.828) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=best;, score=(train=0.874, test=0.864) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.586, test=0.586) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.567, test=0.565) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=4, max_features=log2, splitter=random;, score=(train=0.710, test=0.707) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.925, test=0.912) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.918, test=0.912) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.915, test=0.911) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.755, test=0.748) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.773, test=0.771) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.797, test=0.791) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.906, test=0.894) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.905, test=0.902) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=best;, score=(train=0.917, test=0.901) total time=   0.0s
# [CV 1/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.609, test=0.616) total time=   0.0s
# [CV 2/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.731, test=0.738) total time=   0.0s
# [CV 3/3] END criterion=entropy, max_depth=5, max_features=log2, splitter=random;, score=(train=0.658, test=0.645) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.882, test=0.878) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.888, test=0.886) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=best;, score=(train=0.887, test=0.876) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.643, test=0.630) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.740, test=0.744) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=sqrt, splitter=random;, score=(train=0.695, test=0.690) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=(train=0.800, test=0.803) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=(train=0.816, test=0.815) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=best;, score=(train=0.786, test=0.786) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=(train=0.685, test=0.692) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=(train=0.530, test=0.531) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=3, max_features=log2, splitter=random;, score=(train=0.716, test=0.710) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.904, test=0.887) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.911, test=0.909) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=best;, score=(train=0.908, test=0.901) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.738, test=0.738) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.714, test=0.716) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=sqrt, splitter=random;, score=(train=0.700, test=0.695) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=(train=0.900, test=0.891) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=(train=0.850, test=0.853) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=best;, score=(train=0.891, test=0.884) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=(train=0.578, test=0.582) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=(train=0.687, test=0.693) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=4, max_features=log2, splitter=random;, score=(train=0.732, test=0.729) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=best;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=auto, splitter=random;, score=(train=nan, test=nan) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.919, test=0.905) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.914, test=0.903) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=best;, score=(train=0.918, test=0.906) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.782, test=0.773) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.728, test=0.721) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=sqrt, splitter=random;, score=(train=0.750, test=0.744) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=(train=0.912, test=0.902) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=(train=0.894, test=0.885) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=best;, score=(train=0.915, test=0.903) total time=   0.0s
# [CV 1/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=(train=0.643, test=0.653) total time=   0.0s
# [CV 2/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=(train=0.683, test=0.688) total time=   0.0s
# [CV 3/3] END criterion=log_loss, max_depth=5, max_features=log2, splitter=random;, score=(train=0.687, test=0.683) total time=   0.0s
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:542: FitFailedWarning:
# 54 fits failed out of a total of 162.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 54 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 890, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 1344, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.83816596 0.68375766 0.77534182 0.54891561
#         nan        nan 0.8922678  0.73290901 0.8751768  0.65605846
#         nan        nan 0.90452617 0.77074493 0.87753418 0.64085337
#         nan        nan 0.86338991 0.62553041 0.85902876 0.64792551
#         nan        nan 0.88413484 0.74021688 0.86209335 0.61940123
#         nan        nan 0.91171617 0.76968411 0.89922207 0.66631306
#         nan        nan 0.88000943 0.68800094 0.80127298 0.64427157
#         nan        nan 0.89922207 0.71652522 0.87635549 0.66772749
#         nan        nan 0.9047619  0.74611033 0.89662895 0.67456388]
#   warnings.warn(
# C:\Users\Admin\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the train scores are non-finite: [       nan        nan 0.84682933 0.68281471 0.78294437 0.55162659
#         nan        nan 0.89904526 0.73573786 0.88254361 0.6614215
#         nan        nan 0.9184347  0.7708628  0.88708157 0.64338755
#         nan        nan 0.87441066 0.63154173 0.86639557 0.65358322
#         nan        nan 0.8943305  0.74275106 0.8681636  0.62122819
#         nan        nan 0.91920085 0.77481141 0.90941773 0.66625413
#         nan        nan 0.8856082  0.69277463 0.80038897 0.64374116
#         nan        nan 0.90759076 0.71752711 0.88036304 0.66560585
#         nan        nan 0.91678454 0.75347713 0.90688355 0.67096888]
#   warnings.warn(

# %%
grid_model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'max_features': 'sqrt',
#  'splitter': 'best'}
