# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../df_new_mean_train.csv")
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#         0     1    2            3             4            5             6  \
# 0     3.0  58.0  1.0   450.600000      1.640000   450.600000    526.440000
# 1     3.0  41.0  0.0   357.000000      1.923077   357.076923    538.840237
# 2     3.0  76.0  0.0   478.105263      1.041551   479.052632    345.839335
# 3     3.0  27.0  1.0   587.066667    357.262222   587.866667    663.182222
# 4     2.0  76.0  0.0   900.600000     95.240000   900.600000    170.440000
# ...   ...   ...  ...          ...           ...          ...           ...
# 8479  0.0  64.0  0.0   612.800000  29298.560000   611.733333  28027.128889
# 8480  3.0  75.0  0.0   418.956522   2734.563327   418.956522   2523.780718
# 8481  1.0  58.0  1.0  1235.428571    700.244898  1235.714286    897.632653
# 8482  2.0  75.0  1.0   823.800000   4775.560000   824.000000   4056.000000
# 8483  1.0  66.0  1.0  1100.000000   3967.000000  1095.500000   6184.750000
#
#                 7             8          9  ...            245       246  \
# 0      446.500000   5097.950000  -8.700000  ...   80062.392773  0.670011
# 1      356.076923  11891.224852  -1.307692  ...   76406.068692  0.850813
# 2      478.210526   2771.745152   0.315789  ...   85871.392384  0.489407
# 3      584.533333   6410.382222  -0.800000  ...  103785.759900  1.091541
# 4      905.000000  10025.000000   2.800000  ...   81079.175405  0.800294
# ...           ...           ...        ...  ...            ...       ...
# 8479   614.933333  28417.528889  -5.866667  ...  100877.375033  0.305497
# 8480   419.478261   8352.075614  -3.565217  ...   81455.005289  0.448115
# 8481  1248.285714  15626.775510  16.857143  ...   81763.393500  0.092227
# 8482   804.000000  11132.800000 -22.600000  ...   66478.783260  1.024300
# 8483  1091.000000   5050.000000 -16.250000  ...   55993.608000  0.410091
#
#            247       248          249   250   251   252         253        254
# 0    -0.912051  0.018315   242.648806  21.0  21.0  21.0   -1.714518   3.600000
# 1    -0.498918 -0.076761   974.391877  27.0  27.0  27.0    8.932387  -1.307692
# 2    -0.973497  0.262626    25.275439  20.0  20.0  20.0    6.346053   0.526316
# 3    -0.392591 -0.159420     9.601546  16.0  16.0  16.0   11.755690  -0.666667
# 4    -0.779998 -0.343434    11.737973  11.0  11.0  11.0 -143.141574   2.800000
# ...        ...       ...          ...   ...   ...   ...         ...        ...
# 8479 -1.525075 -0.201948  2438.340543  15.0  15.0  15.0   24.802373   8.571429
# 8480 -1.260327  0.309823    32.322927  24.0  24.0  24.0    5.947163  -3.565217
# 8481 -1.692873  0.599331    10.950366   8.0   8.0   8.0   18.149394  18.571429
# 8482 -0.596278  0.147300   335.316688  11.0  11.0  11.0    4.484999 -20.400000
# 8483 -1.525947 -0.070707    76.835189   8.0   8.0   8.0    4.645446 -18.285714
#
# [8484 rows x 255 columns]

# %%
x_train = df.iloc[:,1:].values
y_train = df.iloc[:,0].values

# %%
X = x_train
y = y_train

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
X = sc.fit_transform(X)

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
model = SVC()
params = {
    'kernel': ['rbf', 'sigmoid', 'poly', 'linear'],
    'C': [0.01, 0.1, 1, 10, 100],
    'gamma': ['scale', 'auto'],
    'probability': [True]
}
grid_search = GridSearchCV(estimator=model, param_grid=params, cv=3, verbose=5, return_train_score=True,refit=True)
grid_model = grid_search.fit(X,y)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [CV 1/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.738, test=0.742) total time= 1.1min
# [CV 2/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.736, test=0.744) total time= 2.1min
# [CV 3/3] END C=0.01, gamma=scale, kernel=rbf, probability=True;, score=(train=0.743, test=0.731) total time= 2.0min
# [CV 1/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 2.4min
# [CV 2/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 1.4min
# [CV 3/3] END C=0.01, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 1.3min
# [CV 1/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.807, test=0.810) total time=  23.9s
# [CV 2/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.806, test=0.810) total time=  27.0s
# [CV 3/3] END C=0.01, gamma=scale, kernel=poly, probability=True;, score=(train=0.818, test=0.796) total time=  28.1s
# [CV 1/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.803, test=0.805) total time=  26.2s
# [CV 2/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.804, test=0.808) total time=  29.5s
# [CV 3/3] END C=0.01, gamma=scale, kernel=linear, probability=True;, score=(train=0.813, test=0.798) total time=  28.7s
# [CV 1/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.384, test=0.383) total time= 1.5min
# [CV 2/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.384, test=0.385) total time= 1.4min
# [CV 3/3] END C=0.01, gamma=auto, kernel=rbf, probability=True;, score=(train=0.385, test=0.383) total time= 1.3min
# [CV 1/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 1.0min
# [CV 2/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 1.1min
# [CV 3/3] END C=0.01, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.367, test=0.367) total time= 1.2min
# [CV 1/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.2min
# [CV 2/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.3min
# [CV 3/3] END C=0.01, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.3min
# [CV 1/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.803, test=0.805) total time=  24.0s
# [CV 2/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.804, test=0.808) total time=  24.7s
# [CV 3/3] END C=0.01, gamma=auto, kernel=linear, probability=True;, score=(train=0.813, test=0.798) total time=  23.1s
# [CV 1/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.809, test=0.811) total time=  30.4s
# [CV 2/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.808, test=0.813) total time=  30.9s
# [CV 3/3] END C=0.1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.816, test=0.803) total time=  30.1s
# [CV 1/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.573, test=0.574) total time= 1.2min
# [CV 2/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.572, test=0.573) total time= 1.3min
# [CV 3/3] END C=0.1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.574, test=0.574) total time= 1.3min
# [CV 1/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.855, test=0.845) total time=  14.9s
# [CV 2/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.851, test=0.853) total time=  14.6s
# [CV 3/3] END C=0.1, gamma=scale, kernel=poly, probability=True;, score=(train=0.859, test=0.831) total time=  13.9s
# [CV 1/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.847, test=0.842) total time=  13.7s
# [CV 2/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.844, test=0.844) total time=  14.6s
# [CV 3/3] END C=0.1, gamma=scale, kernel=linear, probability=True;, score=(train=0.855, test=0.828) total time=  14.1s
# [CV 1/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.707, test=0.717) total time= 1.1min
# [CV 2/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.711, test=0.711) total time= 1.1min
# [CV 3/3] END C=0.1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.718, test=0.709) total time= 1.1min
# [CV 1/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.599, test=0.612) total time=  54.0s
# [CV 2/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.603, test=0.600) total time=  55.0s
# [CV 3/3] END C=0.1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.605, test=0.593) total time=  57.3s
# [CV 1/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.1min
# [CV 2/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.2min
# [CV 3/3] END C=0.1, gamma=auto, kernel=poly, probability=True;, score=(train=0.367, test=0.367) total time= 1.0min
# [CV 1/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.847, test=0.842) total time=  18.9s
# [CV 2/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.844, test=0.844) total time=  15.2s
# [CV 3/3] END C=0.1, gamma=auto, kernel=linear, probability=True;, score=(train=0.855, test=0.828) total time=  13.3s
# [CV 1/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.858, test=0.851) total time=  19.9s
# [CV 2/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.857, test=0.858) total time=  19.7s
# [CV 3/3] END C=1, gamma=scale, kernel=rbf, probability=True;, score=(train=0.868, test=0.837) total time=  18.0s
# [CV 1/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.654, test=0.647) total time=  46.0s
# [CV 2/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.652, test=0.654) total time=  52.1s
# [CV 3/3] END C=1, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.651, test=0.655) total time=  45.4s
# [CV 1/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.894, test=0.868) total time=  13.1s
# [CV 2/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.892, test=0.868) total time=  13.0s
# [CV 3/3] END C=1, gamma=scale, kernel=poly, probability=True;, score=(train=0.898, test=0.856) total time=  13.0s
# [CV 1/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.872, test=0.854) total time=  12.0s
# [CV 2/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.872, test=0.863) total time=   9.4s
# [CV 3/3] END C=1, gamma=scale, kernel=linear, probability=True;, score=(train=0.876, test=0.850) total time=   7.9s
# [CV 1/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.795, test=0.801) total time=  22.1s
# [CV 2/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.796, test=0.800) total time=  22.3s
# [CV 3/3] END C=1, gamma=auto, kernel=rbf, probability=True;, score=(train=0.805, test=0.791) total time=  21.0s
# [CV 1/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.772, test=0.779) total time=  19.7s
# [CV 2/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.773, test=0.777) total time=  19.9s
# [CV 3/3] END C=1, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.784, test=0.767) total time=  17.6s
# [CV 1/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.480, test=0.485) total time=  21.0s
# [CV 2/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.501, test=0.501) total time=  32.9s
# [CV 3/3] END C=1, gamma=auto, kernel=poly, probability=True;, score=(train=0.484, test=0.480) total time=  37.4s
# [CV 1/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.872, test=0.854) total time=  13.3s
# [CV 2/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.872, test=0.863) total time=  11.0s
# [CV 3/3] END C=1, gamma=auto, kernel=linear, probability=True;, score=(train=0.876, test=0.850) total time=   8.2s
# [CV 1/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.907, test=0.878) total time=  11.8s
# [CV 2/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.906, test=0.876) total time=  11.1s
# [CV 3/3] END C=10, gamma=scale, kernel=rbf, probability=True;, score=(train=0.908, test=0.859) total time=  10.5s
# [CV 1/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.591, test=0.594) total time=  15.5s
# [CV 2/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.604, test=0.600) total time=  15.5s
# [CV 3/3] END C=10, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.609, test=0.598) total time=  15.0s
# [CV 1/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.946, test=0.877) total time=  10.4s
# [CV 2/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.946, test=0.871) total time=  10.0s
# [CV 3/3] END C=10, gamma=scale, kernel=poly, probability=True;, score=(train=0.948, test=0.865) total time=   9.8s
# [CV 1/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.896, test=0.866) total time=  10.2s
# [CV 2/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.892, test=0.864) total time=  10.3s
# [CV 3/3] END C=10, gamma=scale, kernel=linear, probability=True;, score=(train=0.897, test=0.855) total time=   9.9s
# [CV 1/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.847, test=0.841) total time=  13.8s
# [CV 2/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.845, test=0.843) total time=  13.8s
# [CV 3/3] END C=10, gamma=auto, kernel=rbf, probability=True;, score=(train=0.852, test=0.826) total time=  13.8s
# [CV 1/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.834, test=0.830) total time=  11.7s
# [CV 2/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.830, test=0.834) total time=  11.9s
# [CV 3/3] END C=10, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.841, test=0.819) total time=  11.6s
# [CV 1/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.748, test=0.754) total time=  21.5s
# [CV 2/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.749, test=0.748) total time=  22.2s
# [CV 3/3] END C=10, gamma=auto, kernel=poly, probability=True;, score=(train=0.754, test=0.744) total time=  23.5s
# [CV 1/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.896, test=0.866) total time=  10.4s
# [CV 2/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.892, test=0.864) total time=  10.5s
# [CV 3/3] END C=10, gamma=auto, kernel=linear, probability=True;, score=(train=0.897, test=0.855) total time=  10.0s
# [CV 1/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.966, test=0.880) total time=  12.7s
# [CV 2/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.964, test=0.874) total time=  12.2s
# [CV 3/3] END C=100, gamma=scale, kernel=rbf, probability=True;, score=(train=0.965, test=0.872) total time=  11.9s
# [CV 1/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.566, test=0.564) total time=  11.3s
# [CV 2/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.580, test=0.573) total time=  13.0s
# [CV 3/3] END C=100, gamma=scale, kernel=sigmoid, probability=True;, score=(train=0.573, test=0.577) total time=  12.3s
# [CV 1/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.985, test=0.861) total time=  19.1s
# [CV 2/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.986, test=0.862) total time=  19.2s
# [CV 3/3] END C=100, gamma=scale, kernel=poly, probability=True;, score=(train=0.989, test=0.859) total time=  17.5s
# [CV 1/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.918, test=0.869) total time=  36.1s
# [CV 2/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.912, test=0.864) total time=  37.2s
# [CV 3/3] END C=100, gamma=scale, kernel=linear, probability=True;, score=(train=0.920, test=0.853) total time=  36.4s
# [CV 1/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.876, test=0.854) total time=  11.2s
# [CV 2/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.872, test=0.864) total time=  11.3s
# [CV 3/3] END C=100, gamma=auto, kernel=rbf, probability=True;, score=(train=0.879, test=0.851) total time=  10.8s
# [CV 1/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.861, test=0.850) total time=   9.3s
# [CV 2/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.859, test=0.853) total time=   9.0s
# [CV 3/3] END C=100, gamma=auto, kernel=sigmoid, probability=True;, score=(train=0.865, test=0.841) total time=   9.0s
# [CV 1/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.819, test=0.824) total time=  12.1s
# [CV 2/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.821, test=0.824) total time=  12.3s
# [CV 3/3] END C=100, gamma=auto, kernel=poly, probability=True;, score=(train=0.832, test=0.811) total time=  12.7s
# [CV 1/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.918, test=0.869) total time=  36.9s
# [CV 2/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.912, test=0.864) total time=  34.2s
# [CV 3/3] END C=100, gamma=auto, kernel=linear, probability=True;, score=(train=0.920, test=0.853) total time=  35.4s

# %%
grid_model.best_params_
# Out:
# {'C': 100, 'gamma': 'scale', 'kernel': 'rbf', 'probability': True}

# %%
grid_model.best_score_
# Out:
# 0.8757661480433757
